# %%
import pandas as pd
import numpy as np
import re

# %%
class MultinomialNaiveBayes:
    def __init__(self, alpha=1):
        self.alpha = alpha  # Laplace smoothing parameter
        self.classes = None
        self.class_word_counts = {}  # {class_label: {word: count}}
        self.class_counts = {}  # {class_label: count}
        self.vocab = set()

    def preprocess_text(self, text):
        # Convert text to lowercase
        text = text.lower()
        # Remove special characters, multiple spaces, and newlines
        text = re.sub(r'[^a-zA-Z\s]', '', text)
        text = re.sub(r'\s+', ' ', text)
        text = text.strip()
        return text

    def fit(self, X, y):
        self.classes = np.unique(y)
        for c in self.classes:
            self.class_word_counts[c] = {}
            self.class_counts[c] = 0
        self.vocab = set()

        for i in range(len(X)):
            processed_text = self.preprocess_text(X[i])
            for word in processed_text.split():
                self.class_word_counts[y[i]][word] = self.class_word_counts[y[i]].get(word, 0) + 1
                self.class_counts[y[i]] += 1
                self.vocab.add(word)

    def _calculate_log_prior(self, class_label):
        return np.log(self.class_counts[class_label] / np.sum(list(self.class_counts.values())))

    def _calculate_log_likelihood(self, x, class_label):
        log_likelihood = 0
        total_words_in_class = sum(self.class_word_counts[class_label].values()) + len(self.vocab) * self.alpha

        for word in x.split():
            word_count = self.class_word_counts[class_label].get(word, 0) + self.alpha
            log_likelihood += np.log(word_count / total_words_in_class)

        return log_likelihood

    def predict(self, X):
        predictions = []
        for x in X:
            processed_text = self.preprocess_text(x)
            best_class = None
            max_posterior = float('-inf')
            for c in self.classes:
                log_prior = self._calculate_log_prior(c)
                log_likelihood = self._calculate_log_likelihood(processed_text, c)
                posterior = log_prior + log_likelihood
                if posterior > max_posterior:
                    max_posterior = posterior
                    best_class = c
            predictions.append(best_class)
        return predictions

# %%
# Read dataset from Excel file and split into train and test sets
def read_and_split_dataset(file_path, test_size=0.2):
    df = pd.read_excel(file_path)
    df['text'] = df['text'].apply(lambda x: re.sub(r'[^a-zA-Z\s]', '', x.lower()))  # Preprocess text
    df = df.sample(frac=1).reset_index(drop=True)  # Shuffle rows
    split_index = int(len(df) * (1 - test_size))
    train_data = df.iloc[:split_index]
    test_data = df.iloc[split_index:]
    X_train, y_train = train_data['text'].tolist(), train_data['type'].tolist()
    X_test, y_test = test_data['text'].tolist(), test_data['type'].tolist()
    return X_train, X_test, y_train, y_test

# %%
# Example usage:
file_path = "./datasetA.xlsx"  # Replace with the path to your Excel file
X_train, X_test, y_train, y_test = read_and_split_dataset(file_path)

# %%
# Create and train the classifier
classifier = MultinomialNaiveBayes(alpha=1)
classifier.fit(X_train, y_train)

# %%
# Predict classes for test dataset
predicted_classes = classifier.predict(X_test)
for i, text in enumerate(X_test):
    print("Text:", text)
    print("True Label:", y_test[i])
    print("Predicted Label:", predicted_classes[i])
    print("----------------------")
# Out:
# Text: rt wxyzalicia this just in
#
# bonjovi is coming in concert to pizzapizzaarena on july th
# bryanadams will be joining them
#
#
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt finelinetay imagine going to a paul mccartney concert with harry im so soft  httpstcoyazsgadiqn
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: im actually scared as hell i never went to a concert before
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: i feel so bad for people who didnt see the cats the musical the movie movie in theaters it was truly a magical experience
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: anndaparatha one of my fav movie
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt stuartpstevens people complaining a presidential debate was boring seems off  the whole idea of politics as entertainment is a lot of
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt baruagauri rt if you think hrithiks acting in the movie super not only deserves filmfare or iifa but also deserves national award
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt deanobeidallah realdonaldtrump daily reminder trump is in federal court arguing to end you and your families coverage for preexisti
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: thaddeusmedical has  patents pending and is helping to ensure medical supplies are transported at the correct t httpstcoocmqxmom
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: notoriousbid i really cant believe how bad our education can be in this regard we learned sig abbreviations qd httpstcohpyrlc
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: rt polysmind so medical association is the new tukde tukde gang how many bhakts going to boycott doctors n hospitals n get treated in
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: medical office specialist  salt lake city ut   httpstcoccdczwuf
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt lonelydeer giveaway
#
# since im gonna buy new vernon doll i decided to giveaway my old vernon doll i will choose winner at st f
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: drbatlittle illustrious marriahj sorry but no children who are deemed to be competent usually an age limit httpstcosoywqjygo
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt kaykosmos heartbreaking that a retired officer missed his als meds for  months because his employer changed insurance plans without
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: remember when yoongi said that it would be better if people instead of taking pictures in phone enjoy the concert w httpstcoaiayjdxpo
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt drkhan nawaz sharifs medical report submitted to government dr adnan httpstcosmdyjfjgz
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt bbc a hot air balloon made of recycled plastic bags will fly from london to seoul as part of an art project launched by btstwt
# bts
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt stargirl meet stargirl caraway in stargirl an original movie streaming mar  on disneyplus httpstcomibpwuqu
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: the indian medical association has lambasted pm modi for his deplorable comments on doctors
#
# pm modi allegedly st httpstcoeaxoels
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt drharjitbhatti white coat march against caanrcnpr at amu hundreds of allopathic dental ayurvedic homeopathic doctors amp nurses to
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt mdmagazine after fda committees voted  against recommending the nda for oxycodogel formerly nktr for treating chronic lower
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: dajjrambo i just cant have my good teeth shaved to place fake ones over them with no medical reason like what is this
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: kymdolla yourcorpblkgirl yes been there in n california was bad time  i departed could not stand the workplace s httpstcoehvozpyb
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: rt mrpritam i wish that beingsalmankhan sir also do one historical based movie like tanhaji it will roar on box office what do you say
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: apparently my shitty aunt isnt going to her daughters wedding because she is going to a kenny chesney concert insteadi hate this bitch
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: olivier giroud set for inter milan medical after chelsea reach transfer agreement  cfc transfernews httpstcojayxrwrq
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt mocking gglobalprotestdaytime to rise as one scientists  medical doctors  beekeepers amp  env
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt weeabob so youre telling me youre telling me that this movie with these animations didnt get nominated for an oscar httpstcoq
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: standinghannah the set for the next godzilla movie that thing needs some dinosaurs smashing all of the buildings
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt lotusoak in the video me state senator robert foley testifies in opposition to ld  to remove religious and philosophical vaccin
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: you should not be allowed to go into the medical field if you are antivax
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt parchmanmdoc inmates housed in the filthy parchmanprison were forced to create a fire in order to save the life of another inmate wh
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt bmjlatest medical leaders have warned that doctors and patients are being placed at risk after it emerged that an nhs hospital had e
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: medical assistant  salt lake city ut   httpstcoyizrstda
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt asiannyy looking for medical volunteers
#  internal medicinegen physician
#  pediatrician
#  obgyne
#  pharmacist
#
# we would appreciate
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: daghanag concert sa smx this year oyyy
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt thmoff guys tune into suntv  the world television premiere of bigil movie has started now captain michael intro is on the
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt projectmarch marchonthemove  iampi conferentie
# how can you apply computer science in medical technology our exoskeleton is a great e
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt ohpdps we are mourning the loss of a fellow leo bryan county deputy jarid taylor we helped escort his body to the medical examiner
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt najihahshahrel and also its very unfair for those who actually have depression taking controlled pills attending appointments and ge
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt senatorbennet cos new law to protect patients from surprise medical bills is a strong step forward but we need federal action to end
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt kimvanadium taehyung said having a concert and seeing armys smile heals their soul  httpstcogcfdzwmzp
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt wingsforx one it let your genuine love for our  boys be the fuel to keep you going this fight is not ours alone lets bring our
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt newshd hussain nawaz said latest medical reports of nawaz sharif have been submitted all legal formalities are being fulfilled reg
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt niegh zipline technology made a medical  delivery with their drones  to juansa health centre asante akye north district
#
# thechange
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt llovewoozl this is what carats mean when they say the concert is also a comedy show like wtf is this httpstcolsulrhe
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt mywonflower so who has a screenshot of that loser saying svts prudential center concert was empty i wanna laugh about it httpstc
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: job york united states  medical receptionist  here at the york medical clinic providers and patients d here at httpstcovcoxabmrt
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt cebupacificair cebuadvisory
# maniladubai flight
# january
# cebu pacific flight j  maniladubai diverted to the kolkata air
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: rt rngltrc in light of john lloyd and shainas reunion
#
# vaginismus just like any other disease or disorder is a medical concern which
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: medical assistant  salt lake city ut   httpstcopxmlsbjn
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt vertigowarrior recent movie collections
# good news  cr still running
# dabangg   crs almost done
# chhapaak  crs  days
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt kirschj hey cityofweston  did you know that back in  you joined the ranks of citiesplaces with medical criteria named after th
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: baldheadman are you under the impression medical breakthroughs arent happening in socialist counties  we spend httpstcodwmxovcmb
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt gaywonk cnn is not a news organization
#
# its an entertainment network that profits off of turning democracy into reality tv
#
# democ
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: gedson fernandes to spurs
#  monday  spurs interested in gedson fernandes
#  tuesday  fernandes to have spurs medi httpstcoxrohuspmx
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt geoffreyewarwa moments after checking the agenda and its canaangents lined under entertainment
#
# audience httpstconmhfqau
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt hongkon dr darren mann was part of a medical team to offer humanitarian aid when hong kong police besieged the polytechnic un
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt drkhan dr adnan submits nawaz sharifs latest medical report to govt httpstcopmbhfoivoq
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt diogeneslamp cats whillikerz amysiskind rfhyde he actually was last year confined in a medical facility after being arre
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: brunomars i think charliewilson has laid out in this song a good skit for calling all my lovelies at the next c httpstcoyoalrvul
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt kingoftalk reunited daniel kathryn to work on new series movie together  httpstcogygxkiqmo
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: chocopjw cun lets go to treasure concert together
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt news the commonwealth medical association cma has condemned the assault on a female medical doctor that was reportedly stripped
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt abscbn morissetteamon surely found the love of her life in dave lamar see the rare sweet moments they shared in public here
# htt
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: flonk aalgar because it is there gee whiz flonk did you actually watch the movie
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt srbetler stop  telling  people  theyre  too  young  for   a  medical  condition
#
# unlike bartenders medical conditions do
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt votetheredout if you want a kickass shirt and help a fellow resister with medical bills go to brutalhonesty page and order one htt
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: psychodalla hiraiprnt i sometimes buy twice albums cuz the amounts of goodies they gave out was irresistible eve httpstcopszxvno
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt drkhan nawaz sharifs medical reports submitted to govt authorities says dr adnan  aaj news httpstcoappyioigna
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt sevenflamingos icymi former vice president of insys therapeutics sentenced for racketeering conspiracy
#
# defendant is the first ex
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: can you recommend anyone for this job medical secretary  httpstcowdnztcdlc clerical boston ma
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt thv rattlesnake ridge has become a very popular destination for mountain bike enthusiasts
#
# httpstcoqacfuxbu httpstcoxom
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt thestagertv pattas tamil movie review by dr r suresh kumar watch unbiased and standard review
#
# here  httpstcokuawugcbhp
#
# k
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: hussain nawaz said latest medical reports of nawaz sharif have been submitted all legal formalities are being ful httpstcokijlvkwppg
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt chriscb vip standing  nachimbong in skz concert
#
# vip standing  nachimbong in skz concert
#
# vip standing  nachimbong in skz conc
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: medical office specialist  salt lake city ut   httpstcoecgrygljaf
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt alpacnologia dril hey wint did u fall from heaven because u look like u need urgent medical care
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: today i visited the library in the small town i grew up in some things never change youll always find medical st httpstcoypdwyxbdy
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt adamparkhomenko davidcorndc incredible that they have been able to involuntarily confine robert hyde in a medical facility but not do
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: check out hausted bed medical pin lapel hat stretcher gurney hospital advertising surgery  httpstcomjcnwitu via ebay
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: this is a question thatericalper should askwhat is the weirdest concert youve ever been to
#
# i saw dave matthe httpstcopiewrtuz
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: gadhvilaxman biggest traitor i am so happy her movie flopped hope all her movies flop in future such traitor httpstcoclwyqukxtj
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt bangtanindia section tv entertainment news
#
# who is bts closer with among celebrities
#
# note the answer is cut off
#
# btstwt bts
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: just some of the acts ive seen live in concert not at any festival or event the love ive got for music is mad
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: looking to join fresenius medical care jobsfmcna life care or hca healthcare careersathca view  openin httpstcojcnqtmissa
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: medical office specialist  salt lake city ut   httpstcomvjjkgxj
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: medical assistant  salt lake city ut   httpstcovqpgwszb
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt drdanieljhughes adamjanuszewski providing an overview of medical leadership and management and his experience as an fmlmuk fellow t
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt transequality under a proposed bill introduced in the final moments of submission to the  legislative session doctors could face
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt politidope is this a mob movie or a presidency httpstcoopytawe
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt thequint watch what happened when deepikapadukone went undercover with a team of actors to find out how easy it is to purchase acid i
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt akosikenchan beyond excited for rita and i to be the special guests of these two legends of the phillipines mr martin nievera and ms
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: check out acdc rare vintage  stiff upper lip concert t shirt xl mint of a kind httpstcokujircgd ebay httpstcolryqegd
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt renminrise renjun said these days because of a concert and year and stage he was busy so he wasnt able to do a cover if there is a t
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt beacongalen released last year games changers hosted by alex trebek explores the human side of the north american game show industry
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt dlpubliclaw removal deferred of yr old trafficking victim living w hiv following urgent representations now to secure release from
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: rt rosenthalhealth still no criticism of hospitals candidates you talk about unbearable medical bills read our
# npr khnews billofth
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: my dad is excited about me turning  so he can put down my name as the main driver of my car
#
# oh did i also men httpstcoqdwzuejpw
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: rt hawthorl a chance to weigh in on medical assistance in dying httpstcopofpptkyx
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: seeking insights on arizonas medical cannabis market hoping to speak with businesses patients advocates lawmak httpstcoumaxigkrt
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt coconutverbena was only the early part of the concert but jaebeom was soaking wet already  httpstcorzvzqikb
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt poonambenmaadam it was wonderful to hear the melodious voice of shreyaghoshal at the grand musical evening organized by alumni of mp
# True Label: medical
# Predicted Label: entertainment
# ----------------------
# Text: rt footballitalia olivier giroud ought to have his inter medical over the weekend claim sky sport italia after chelsea agreed a m
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt neurophysik it is high time social media platforms like twitter take cognisance of such dangerous medical misinformation and devise a
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: really debating if i should drop a couple rack on this pc or my medical bills
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt filomenalala today new nj bill to restrict exemptions to mandatory vaccination a a bill that requires the hpv vaccines for all st
# True Label: medical
# Predicted Label: medical
# ----------------------
# Text: rt babiejongdae lrt a soondingie tweeted yall are asking whos going to kim jongdae solo con im going so everyone shut up
#
# and
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: liishamac did we watch the same movie i gotta research the real story cause i disagree if we going based off the film
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: avicii tribute concert in loving memory of tim bergling httpstcolcnp via youtube
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
# Text: rt jenstherin remember when jennie debuted her solo at their first korean concert because she wanted blinks to hear it first before anyon
# True Label: entertainment
# Predicted Label: entertainment
# ----------------------
